# %%
from torchvision import datasets

data_path = "imgs/ch7/"
cifar10 = datasets.CIFAR10(data_path, train=True, download=True)
cifar10_validation = datasets.CIFAR10(data_path, train=False, download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
type(cifar10).__mro__
# Out:
# (torchvision.datasets.cifar.CIFAR10,
#  torchvision.datasets.vision.VisionDataset,
#  torch.utils.data.dataset.Dataset,
#  typing.Generic,
#  object)

# %%
len(cifar10)
# Out:
# 50000

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']
img, label = cifar10[99]
(img, label, class_names[label])
# Out:
# (<PIL.Image.Image image mode=RGB size=32x32>, 1, 'automobile')

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
import torchvision.transforms as transforms

transformed_cifar10 = datasets.CIFAR10(
    data_path,
    train=True,
    download=False,
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2470, 0.2435, 0.2616))
    ])
)

img_t, _ = transformed_cifar10[99]

plt.imshow(img_t.permute(1, 2, 0));
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.9802876..2.1264887].

# %%
label_map = {0: 0, 2: 1}
class_names = ['airplane', 'bird']
cifar2 = [(img, label_map[label])
          for img, label in cifar10
          if label in [0, 2]]
cifar2_val = [(img, label_map[label])
              for img, label in cifar10_validation
              if label in [0, 2]]
len(cifar2), len(cifar2_val)
# Out:
# (10000, 2000)

# %%
label_map = {0: 0, 2: 1}
class_names = ['airplane', 'bird']
cifar2 = [(img, label_map[label])
          for img, label in cifar10
          if label in [0, 2]]
cifar2_val = [(img, label_map[label])
              for img, label in cifar10_validation
              if label in [0, 2]]
len(cifar2), len(cifar2_val)
# Out:
# (10000, 2000)

# %%
testImg, _ = cifar2[0]
plt.imshow(testImg)

# %%
testImg, _ = cifar2_val[0]
plt.imshow(testImg)

# %%
import torch.nn as nn

n_out = 2
model = nn.Sequential(
    nn.Linear(3072, 512),
    nn.Tanh(),
    nn.Linear(512, n_out),
)
model
# Out:
# Sequential(
#   (0): Linear(in_features=3072, out_features=512, bias=True)
#   (1): Tanh()
#   (2): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
import torch

def softmax(x):
    return torch.exp(x) / torch.exp(x).sum()

x = torch.tensor([1.0, 2.0, 3.0])
softmax(x), softmax(x).sum()
# Out:
# (tensor([0.0900, 0.2447, 0.6652]), tensor(1.))

# %%
softmax1 = nn.Softmax(dim=1)
x = torch.tensor([[1.0, 2.0, 3.0],
                  [1.0, 2.0, 3.0]])
softmax1(x)
# Out:
# tensor([[0.0900, 0.2447, 0.6652],
#         [0.0900, 0.2447, 0.6652]])

# %%
softmax1 = nn.Softmax(dim=0)
x = torch.tensor([[1.0, 2.0, 3.0],
                  [1.0, 2.0, 3.0]])
softmax1(x)
# Out:
# tensor([[0.5000, 0.5000, 0.5000],
#         [0.5000, 0.5000, 0.5000]])

# %%
transformed_cifar10 = datasets.CIFAR10(data_path,
                                       train=True,
                                       download=False,
                                       transform=transforms.Compose([
                                           transforms.ToTensor(),
                                           transforms.Normalize(imgs_mean, imgs_std)
                                       ]))

transformed_cifar10_validation = datasets.CIFAR10(data_path,
                                                  train=False,
                                                  download=False,
                                                  transform=transforms.Compose([
                                                      transforms.ToTensor(),
                                                      transforms.Normalize(imgs_mean, imgs_std)
                                                  ]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 6
#       1 transformed_cifar10 = datasets.CIFAR10(data_path,
#       2                                        train=True,
#       3                                        download=False,
#       4                                        transform=transforms.Compose([
#       5                                            transforms.ToTensor(),
# ----> 6                                            transforms.Normalize(imgs_mean, imgs_std)
#       7                                        ]))
#       9 transformed_cifar10_validation = datasets.CIFAR10(data_path,
#      10                                                   train=False,
#      11                                                   download=False,
#    (...)
#      14                                                       transforms.Normalize(imgs_mean, imgs_std)
#      15                                                   ]))
#
# NameError: name 'imgs_mean' is not defined

# %%
img, _ = cifar2[0]
img_batch = img.view(-1).unsqueeze(0)
plt.imshow(img.permute(1, 2, 0))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 2
#       1 img, _ = cifar2[0]
# ----> 2 img_batch = img.view(-1).unsqueeze(0)
#       3 plt.imshow(img.permute(1, 2, 0))
#
# AttributeError: 'Image' object has no attribute 'view'
